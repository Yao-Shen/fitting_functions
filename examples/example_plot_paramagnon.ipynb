# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from fitting_functions.extra_lineshapes import paramagnon

# %matplotlib nbagg

# %%
x = np.linspace(-1, 2, 1000)
#                amplitude, center, sigma, res, kBT)
y = paramagnon(x, 1,      0.3,       .5, 0.0001, 10*8.617e-5)

fig, ax = plt.subplots()

ax.plot(x, y)
# Out:
# /Users/markdean/anaconda/envs/main/lib/python3.6/site-packages/fitting_functions-0.0.0-py3.6.egg/fitting_functions/extra_lineshapes.py:44: RuntimeWarning: overflow encountered in exp
# <img src="data:image/png;base64,..." width="640">
